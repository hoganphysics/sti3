# %%
from stipy import *
import testDevice

# %%
testDevice.device1

# %%
configFile = ConfigFile("testDevice.ini")

# %%
configFile.set("a", "5")
# Out:
# <'', 'NetworkHub', 'TestDevice1', 'TestDevice1.SetupData', 'TestDevice2'>

# %%
configFile.get("a")
# Out:
# '5'

# %%
configFile.getList("TestDevice1.SetupData", "example")
# Out:
# ['1', '3.7', '5']

# %%
configFile.addToList("TestDevice1.SetupData", "example", '35')
configFile.getList("TestDevice1.SetupData", "example")
# Out:
# ['1', '3.7', '5', '35']

# %%
config = Configuration(
    {'Device Name': 'TestDevice',
     'IP Address': 'localhost',
     'Module': '0',
     'Target Server': 'localhost/0/STI Server'})

# %%
config.getParameterNames()
# Out:
# ['Device Name', 'IP Address', 'Module', 'Target Server']

# %%
help(LocalDevice)
# Out:
# Help on class LocalDevice in module stipy.bin.stidevicepy:
#
# class LocalDevice(Device)
#  |  Method resolution order:
#  |      LocalDevice
#  |      Device
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(...)
#  |      __init__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __init__(self: stipy.bin.stidevicepy.LocalDevice, config: Dict[str, str]) -> None
#  |
#  |      2. __init__(self: stipy.bin.stidevicepy.LocalDevice, config: stipy.bin.stipybase.Configuration) -> None
#  |
#  |      3. __init__(self: stipy.bin.stidevicepy.LocalDevice, config: stipy.bin.stipybase.Configuration, section: str) -> None
#  |
#  |      4. __init__(self: stipy.bin.stidevicepy.LocalDevice, name: str, address: str, module: int, targetServerID: str) -> None
#  |
# ...

# %%
help(LocalDevice.read)
# Out:
# Help on instancemethod in module stipy.bin.stidevicepy:
#
# read(...)
#     read(*args, **kwargs)
#     Overloaded function.
#
#     1. read(self: stipy.bin.stidevicepy.Device, channelNumber: int) -> object
#
#     2. read(self: stipy.bin.stidevicepy.Device, channelNumber: int, value: object) -> object
