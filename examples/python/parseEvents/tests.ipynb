# %%
from stipy import *

# %%
testDevice = connect("localhost/0/TestDevice", "192.168.1.4:2809")
# Out:
# ++++ add( localhost/0/TestDevice )

# %%
testDevice.read(2)
# Out:
# 9.0
# ---- remove( localhost/0/TestDevice )

# %%
testDevice.write(1, 9.5)
# Out:
# True

# %%
server = connect("localhost/0/STI Server", "192.168.1.4:2809")
# Out:
# ++++ add( localhost/0/STI Server )

# %%
td = server.getDeviceCollection().get("localhost/0/TestDevice")

# %%
td.read(2)
# Out:
# 9.0

# %%
def f():
    meas(ch(dev("TestDevice", "localhost", 0), 2), 200*1000)
    event(ch(dev("TestDevice", "localhost", 0), 1), 200*1000 + 1*200*1000, 5.7)
    return

s = testDevice.makeshot(f)
tick = testDevice.parse(s)

# s = server.makeshot(f)
# tick = server.parse(s)

# %%
tick.messages()
# Out:
# []

# %%
res = testDevice.play(tick)

# %%
res.getShotResult().getMeasurements()
# Out:
# {localhost/0/TestDevice: [<Time=200us|0ns, Channel=2, Type=Double, Value=9>]}

# %%
res = server.play(tick)

# %%
dir(res)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'cancel',
#  'defer',
#  'getParseResult',
#  'getShotID',
#  'getShotResult',
#  'measurements',
#  'status',
#  'wait']

# %%
res.getParseResult().messages
# Out:
# [<Python Exception|Traceback (most recent call last):
#    File "/home/hogan/code/dev/sti3/env/lib/python3.10/site-packages/stipy/stidevicepy/python/localdevice.py", line 27, in _parseEventsWrapper
#      self.parseEvents(eventsIn, synchedEvents)
#    File "/home/hogan/code/dev/sti3/examples/python/parseEvents/testDevice.py", line 59, in parseEvents
#      y=x[3]
#  IndexError: list index out of range
#  >]

# %%
res.measurements()
# Out:
# {}
# ---- remove( localhost/0/TestDevice )

# %%
testDevice.getEngineScheduler().cancelAll()

# %%
testDevice.getEngineScheduler().jobIDs(EventEngineJobList.Running)
# Out:
# []

# %%
testDevice.getEngineScheduler().cancelJob(tmp[0])

# %%
tick.status()
# Out:
# <TicketStatus.Complete: 1>

# %%
server.getEngineScheduler().jobIDs(EventEngineJobList.Running)
# Out:
# []

# %%
server.getEngineScheduler().cancelAll()

# %%
tick.cancel()

# %%
dir(tick.getParseResult())
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'baseEventGroup',
#  'messages',
#  'parsedDevices',
#  'pid',
#  'stackTraceResult']

# %%
tick.messages()
# Out:
# []

# %%
tick.getParseResult().messages
# Out:
# []

# %%
dir(res.getShotResult())
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'attributes',
#  'getMeasurements',
#  'playTime',
#  'shotResultRecord',
#  'sid']

# %%
res.getShotResult().getMeasurements()
# Out:
# {localhost/0/TestDevice: [<Time=200us|0ns, Channel=2, Type=Double, Value=9>]}

# %%
res.measurements()
# Out:
# {}

# %%
dir(stipy.LocalDevice)

# %%
dir(stipy.LocalDevice)

# %%
help(stipy.LocalDevice.parseEvents2)

# %%
help(stipy.LocalDevice)
