# %%
from stipy import *

# %%
did = DeviceID("TestDevice", "localhost", 0)
# Out:
# localhost/0/TestDevice

# %%
testDevice = connect("localhost/0/TestDevice", "192.168.1.4:2809")
# Out:
# ++++ add( localhost/0/TestDevice )

# %%
dir(RawEvent)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'channel',
#  'description',
#  'getEventGraphPath',
#  'getGroupName',
#  'getStackTrace',
#  'printTime',
#  'target',
#  'time',
#  'type',
#  'value']
# ---- remove( localhost/0/TestDevice )

# %%
testDevice.read(2)
