# %% [markdown]
# # Image read
#
# Start the readWrite example device, read one image channel, and open it with Pillow.

# %%
from pathlib import Path
import subprocess
import sys
import time

import stipy
from PIL import Image as PILImage


name_service = "192.168.88.252:2809"
device_process = subprocess.Popen([sys.executable, "testDevice.py"])
time.sleep(2.0)

device = stipy.connect(stipy.DeviceID("TestDevice", "localhost", 0), name_service)
device
# Out:
# Ch:0, coil current: 12.7
# Ch:1, temperature setpoint: 32
# Ch:2, supply voltage: 2.5
# Ch:3, list output: [11, test, 0]
#      *vector arg types match!
#      *args: [11, test, 0]
# Ch:4, string output: test string
# Read Ch:10, in value: None
# Measurement 1: 34.5
# Read ch 11: [12, hi]
# Measurement 2: 146.39999999999998
# Read ch 12: 23.4
# Measurement 3: [74.88, example string result, 1]
# Read ch 15: example PNG image
# Measurement 4: <Image | 1x1 | 68 bytes>
# ++++ add( maximus/0/STIPy:maximus:2026-07-19:13_01_32_001720963 )
# localhost/0/TestDevice
# ++++ add( localhost/0/TestDevice )
# ++++ add( localhost/0/TestDevice )
# ++++ add( maximus/0/STIPy:maximus:2026-07-19:13_01_32_001720963 )

# %% [markdown]
# Channel 15 returns a file-backed `Image`. Transfer it into Python memory and decode it with Pillow.

# %%
image = device.read(15)
pil_image = image.to_pil(device)
pil_image
# Out:
# Read ch 15: example PNG image
# <PIL.PngImagePlugin.PngImageFile image mode=LA size=1x1>
# Read ch 15: example PNG image
# Read ch 15: example PNG image
# Read ch 15: example PNG image
# ++++ add( maximus/0/STIPy:maximus:2026-07-19:13_01_32_001720963 )
# ++++ add( localhost/0/TestDevice )
# ++++ add( maximus/0/STIPy:maximus:2026-07-19:13_01_32_001720963 )
# ++++ add( localhost/0/TestDevice )

# %% [markdown]
# Transfer the same image to a local file, then open that file with Pillow.

# %%
image_path = Path("image_read.png")
image.to_file(image_path, device)

pil_image_from_file = PILImage.open(image_path)
pil_image_from_file.load()
pil_image_from_file

# %%
device_process.terminate()
