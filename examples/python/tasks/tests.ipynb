# %%
from stipy import *

# %%
testDevice = connect("localhost/0/TestDevice", "192.168.1.4:2809")
# Out:
# ++++ add( localhost/0/TestDevice )

# %%
tm = testDevice.getTaskManager()

# %%
tm.getTaskIDs()
# Out:
# {'task#1', 'task#2', 'task#3'}

# %%
tm.deactivateTask("task#1")

# %%
tm.activateTask("task#1")

# %%
tm.runTask("task#2")

# %%
tm.getTaskStatus("task#3")
# Out:
# <TaskStatus.Active: 0>

# %%
task2 = tm.getTask("task#2")

# %%
task2.getStatus()
# Out:
# <TaskStatus.Active: 0>

# %%
task2.getID()
# Out:
# 'task#2'

# %%
task2.secondsToNextRun()
# Out:
# 86333.235
# ---- remove( localhost/0/TestDevice )

# %%
task2.run()
