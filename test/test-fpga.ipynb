# %%
from stipy import *

# %%
server = connect(DeviceID("Frame2", "sr-magis", 2), "192.168.1.109:2809")
# Out:
# ++++ add( sr-magis/2/Frame2 )

# %%
server.getDeviceCollection().getIDs()
# Out:
# [localhost/0/TestDevice,
#  localhost/0/TestDevice2,
#  maximus/0/STIPy:maximus:2026-01-15:22_33_53_115385153,
#  sr-timing2/0/DDS,
#  sr-timing2/1/Fast Analog Out,
#  sr-timing2/2/Digital Out,
#  sr-timing2/4/Slow Analog Out,
#  sr-timing2/8/FPGA Trigger,
#  sr-timing2/9/FPGA Memory]
# ---- remove( sr-magis/2/Frame2 )

# %%
server.refresh()
# Out:
# True

# %%
printNetwork("STI")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 printNetwork("STI")
#
# TypeError: printNetwork(): incompatible function arguments. The following argument types are supported:
#     1. (arg0: str, arg1: str) -> str
#
# Invoked with: 'STI'

# %%
print(printNetwork("192.168.1.109:2809", "STI"))
# Out:
# *STI
# **localhost
# ***0
# ****Hub::TestDevice
# *****TDeviceHub.Object (Alive)
# ****Hub::TestDevice2
# *****TDeviceHub.Object (Alive)
# **sr-magis
# ***2
# ****Hub::Frame2
# *****sr-timing2
# ******8
# *******Hub::FPGA Trigger
# ********TDeviceHub.Object (Alive)
# *****localhost
# ******0
# *******Hub::TestDevice2
# ********TDeviceHub.Object (Alive)
# *******Hub::TestDevice
# ********TDeviceHub.Object (Alive)
# *****TDeviceHub.Object (Alive)
# **sr-timing2
# ***8
# ****Hub::FPGA Trigger
# *****TDeviceHub.Object (Alive)
# **Spartan6
# ***FPGA.Object (Alive)

# %%
config = Configuration()

config.set("omniORB", "traceLevel", "0")
# config.set("omniORB", "endPoint", "giop:tcp::2820")
# config.set("omniORB", "endPointPublish", "giop:tcp:192.168.1.109:2820")

config.set("omniORB", "scanGranularity", "1")
config.set("omniORB", "clientConnectTimeOutPeriod", "200")  # milliseconds
config.set("omniORB", "clientCallTimeOutPeriod", "200")  # milliseconds
# Out:
# <'omniORB'>

# %%
server = connect(DeviceID("Frame2", "sr-magis", 2), "192.168.1.109:2809", config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 server = connect(DeviceID("Frame2", "sr-magis", 2), "192.168.1.109:2809", config)
#
# NameError: name 'config' is not defined

# %%
server = connect(DeviceID("STI Server", "localhost", 0), "192.168.1.119:2809")
# Out:
# Caught a CORBA::TIMEOUT while using the naming service.
# Caught a CORBA::TIMEOUT while using the naming service.
# Connect: Failed to find Hub for deviceID 'localhost/0/STI Server'

# %%
server = connect(DeviceID("Digital Out", "sr-timing2", 2), "192.168.1.109:2809")
# Out:
# ++++ add( sr-timing2/2/Digital Out )

# %%
server.getID()
# Out:
# sr-timing2/2/Digital Out

# %%
server.getDeviceCollection().getIDs()
# Out:
# [maximus/0/STIPy:maximus:2026-01-15:22_32_43_883412872,
#  sr-timing2/8/FPGA Trigger,
#  sr-timing2/9/FPGA Memory]

# %%
server.printNetwork()
# Out:
# '*STI \n**localhost \n***0 \n****Hub::TestDevice2 \n*****TDeviceHub.Object (Alive)\n****Hub::TestDevice \n*****TDeviceHub.Object (Alive)\n**sr-magis \n***2 \n****Hub::Frame2 \n*****localhost \n******0 \n*******Hub::TestDevice2 \n********TDeviceHub.Object (Alive)\n*******Hub::TestDevice \n********TDeviceHub.Object (Alive)\n*****TDeviceHub.Object (Alive)\n*****sr-timing2 \n******8 \n*******Hub::FPGA Trigger \n********TDeviceHub.Object (Dead)\n**Spartan6 \n***FPGA.Object (Dead)\n**sr-timing2 \n***8 \n****Hub::FPGA Trigger \n*****TDeviceHub.Object (Dead)\n'

# %%
'*STI \n**localhost \n***0 \n****Hub::TestDevice2 \n*****TDeviceHub.Object (Alive)\n****Hub::TestDevice \n*****TDeviceHub.Object (Alive)\n**sr-magis \n***2 \n****Hub::Frame2 \n*****localhost \n******0 \n*******Hub::TestDevice2 \n********TDeviceHub.Object (Alive)\n*******Hub::TestDevice \n********TDeviceHub.Object (Alive)\n*****TDeviceHub.Object (Alive)\n**Spartan6 \n***FPGA.Object (Dead)\n**sr-timing2 \n***8 \n****Hub::FPGA Trigger \n*****TDeviceHub.Object (Dead)\n'

# %%
server.refresh()
# Out:
# True

# %%
server.cancelAll()

# %%
def test_fpga():
    digital = dev("Digital Out", "sr-timing2", 2)
    ns = 1
    us = 1000
    ms = 1000000
    s = 1000000000
    
    time = 10*us

    event(ch(digital, 0), time, True)
    event(ch(digital, 0), time + 20*us, False)
    event(ch(digital, 0), time + 30*us, True)
    event(ch(digital, 0), time + 32*us, False)
    event(ch(digital, 0), time + 36*us, True)

def test_fpga2():
    digital = dev("Digital Out", "sr-timing2", 2)
    ns = 1
    us = 1000
    ms = 1000000
    s = 1000000000
    
    time = 11*us

    event(ch(digital, 0), time, True)
    event(ch(digital, 0), time + 20*us, False)
    event(ch(digital, 0), time + 40*us, True)
    # event(ch(digital, 0), time + 41*us, True)
    # event(ch(digital, 0), time + 42*us, True)

# %%
shot = server.makeshot(test_fpga)

# %%
shot2 = server.makeshot(test_fpga2)

# %%
shot.rootgroup().events()
# Out:
# [event(Time=10us|0ns, Channel=dev(sr-timing2/2/Digital Out).ch(0), Value=1),
#  event(Time=30us|0ns, Channel=dev(sr-timing2/2/Digital Out).ch(0), Value=0),
#  event(Time=40us|0ns, Channel=dev(sr-timing2/2/Digital Out).ch(0), Value=1),
#  event(Time=42us|0ns, Channel=dev(sr-timing2/2/Digital Out).ch(0), Value=0),
#  event(Time=46us|0ns, Channel=dev(sr-timing2/2/Digital Out).ch(0), Value=1)]

# %%
tick = server.parse(shot)

# %%
tick.messages()
# Out:
# []

# %%
playtick = server.play(tick)

# %%
playtick
# Out:
# <ResultTicket | Running | sid:Jason@HOGAN-Book3#21_03_15_623873500>

# %%
server.cancelAll()

# %%
tick1 = server.parse(shot)
tick1.messages()
# Out:
# []

# %%
playtick = server.play(tick1)

# %%
playtick
# Out:
# <ResultTicket | Canceled | sid:Jason@HOGAN-Book3#20_53_43_125942600>

# %%
tick2 = server.parse(shot2)
tick2.messages()
# Out:
# []

# %%
playtick = server.play(tick2)

# %%
playtick.status()
# Out:
# <TicketStatus.Complete: 1>

# %%
import os
import platform
import socket
import ipaddress
import subprocess

def _default_route_ip():
    s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
    s.connect(("8.8.8.8", 1))
    return s.getsockname()[0]

def _default_iface():
    system = platform.system().lower()
    if system == "linux":
        try:
            with open("/proc/net/route", "r", encoding="ascii") as f:
                for line in f.readlines()[1:]:
                    fields = line.strip().split()
                    if len(fields) >= 2 and fields[1] == "00000000":
                        return fields[0]
        except OSError:
            return None
    if system == "darwin":
        try:
            import netifaces  # optional
            return netifaces.gateways()["default"][netifaces.AF_INET][1]
        except Exception:
            pass
        try:
            out = subprocess.check_output(["route", "-n", "get", "default"], text=True)
            for line in out.splitlines():
                line = line.strip()
                if line.startswith("interface:"):
                    return line.split(":", 1)[1].strip()
        except Exception:
            return None
    return None

def publish_ip():
    env_ip = os.getenv("STI3_PUBLISH_IP")
    if env_ip:
        return env_ip

    system = platform.system().lower()
    if system == "windows":
        return _default_route_ip()

    try:
        import fcntl
        import struct
    except ModuleNotFoundError:
        return _default_route_ip()

    def _ifaddr(ifname):
        s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        try:
            return socket.inet_ntoa(
                fcntl.ioctl(
                    s.fileno(),
                    0x8915,  # SIOCGIFADDR
                    struct.pack("256s", ifname[:15].encode("utf-8"))
                )[20:24]
            )
        except OSError:
            return None

    env_subnet = os.getenv("STI3_PUBLISH_SUBNET")
    if env_subnet:
        net = ipaddress.ip_network(env_subnet, strict=False)
        for _, ifname in socket.if_nameindex():
            ip = _ifaddr(ifname)
            if ip and ipaddress.ip_address(ip) in net:
                return ip

    default_iface = _default_iface()
    for _, ifname in socket.if_nameindex():
        if ifname in ("lo", "lo0"):
            continue
        ip = _ifaddr(ifname)
        if ip and ifname != default_iface:
            return ip

    return _default_route_ip()

# %%
publish_ip()
# Out:
# '192.168.1.119'

# %%
import os
import platform
import socket

def _default_route_ip():
    s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
    s.connect(("8.8.8.8", 1))
    return s.getsockname()[0]

def _in_container():
    if os.path.exists("/.dockerenv"):
        return True
    try:
        with open("/proc/1/cgroup", "r", encoding="ascii") as f:
            data = f.read()
        return "docker" in data or "containerd" in data
    except OSError:
        return False

def publish_ip():
    env_ip = os.getenv("STI3_PUBLISH_IP")
    if env_ip:
        return env_ip

    if platform.system().lower() == "windows":
        return _default_route_ip()

    try:
        import fcntl, struct, ipaddress
    except ModuleNotFoundError:
        return _default_route_ip()

    def _ifaddr(ifname):
        s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        try:
            return socket.inet_ntoa(
                fcntl.ioctl(
                    s.fileno(),
                    0x8915,  # SIOCGIFADDR
                    struct.pack("256s", ifname[:15].encode("utf-8"))
                )[20:24]
            )
        except OSError:
            return None

    def _default_iface_linux():
        try:
            with open("/proc/net/route", "r", encoding="ascii") as f:
                for line in f.readlines()[1:]:
                    fields = line.strip().split()
                    if len(fields) >= 2 and fields[1] == "00000000":
                        return fields[0]
        except OSError:
            return None

    # Optional subnet override (Linux)
    env_subnet = os.getenv("STI3_PUBLISH_SUBNET")
    if env_subnet:
        net = ipaddress.ip_network(env_subnet, strict=False)
        for _, ifname in socket.if_nameindex():
            ip = _ifaddr(ifname)
            if ip and ipaddress.ip_address(ip) in net:
                return ip

    ips = {}
    for _, ifname in socket.if_nameindex():
        if ifname == "lo":
            continue
        ip = _ifaddr(ifname)
        if ip:
            ips[ifname] = ip

    if not ips:
        return _default_route_ip()

    if len(ips) == 1:
        return next(iter(ips.values()))

    default_iface = _default_iface_linux()
    if _in_container() and default_iface in ips:
        for ifname, ip in ips.items():
            if ifname != default_iface:
                return ip

    if default_iface in ips:
        return ips[default_iface]

    return next(iter(ips.values()))
