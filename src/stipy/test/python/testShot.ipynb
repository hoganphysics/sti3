# %%
from stipy import *
from makeMOT import *

# %%
s=makeshot("test", f)

# %%
s.getEvents()
# Out:
# [<Time=64ns, Channel=1, Type=Int, Value=89>,
#  <Time=164ns, Channel=1, Type=Int, Value=-5>,
#  <Time=264ns, Channel=1, Type=Int, Value=4>,
#  <Time=564ns, Channel=1, Type=Int, Value=74>]

# %%
s.getVars()
# Out:
# [var(x = 34)]

# %%
s.group().getTags()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Unregistered type : STI::Engine::ParsedTag
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b0aed6a40b3d> in <module>
# ----> 1 s.group().getTags()
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	(self: stipy.bin.stipy.RawEventGroup) -> List[STI::Engine::ParsedTag]

# %%
s.group().var("x")
# Out:
# 34

# %%
s.var("x")
# Out:
# 34
