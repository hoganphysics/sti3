# %%
# %load_ext autoreload
# %autoreload 2

from stipy import *

# %%
did = DeviceID("STI Server", "localhost", 0)
server = connect(did, "192.168.1.14:2809")

# %%
def f():   
    d1 = dev("TestDevice", "localhost", 0)
    meas(ch(d1, 0), 200)

s = server.makeshot(f)
tick = server.parse(s)
tick.wait()
tick.getParseResult().messages
# Out:
# []

# %%
result = server.play(tick)
