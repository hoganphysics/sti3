# %%
# %load_ext autoreload
# %autoreload 2

from stipy import *
from makeMOT import *

# %%
v=MixedValue()
v.addValue(True)
v.addValue(False)
print(v.getValue())
print(v.getType())
# Out:
# [True, False]
# MixedValueType.Vector

# %%
v.getValue()
# Out:
# [True, False]

# %%
v=MixedValue()
v.addValue(9)
print(v.getType())
print(v.getValue())
print(v.getValue()[0])
# Out:
# MixedValueType.VectorInt
# [9]
# 9

# %%
v1=MixedValue(True)
print(v1.getValue())
print(v1.getType())

v2=MixedValue(1)
print(v2.getValue())
print(v2.getType())
# Out:
# True
# MixedValueType.Boolean
# 1
# MixedValueType.Int

# %%
v=MixedValue([[4,5],3])
print(v)
v=MixedValue([3,[4,5]])
print(v)
v=MixedValue([3,4,5])
print(v)
v=MixedValue()
v.setValue([[1,2],3,4])
print(v)
# Out:
# ((4,5),3)
# (3,(4,5))
# (3,4,5)
# ((1,2),3,4)

# %%
v=MixedValue()
v.addValue(3)
v.addValue([4,5])
v
# Out:
# (3,(4,5))

# %%
v=MixedValue()
v.addValue(True)
v.getValue()
# Out:
# [True]
