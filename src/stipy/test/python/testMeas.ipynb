# %%
# %load_ext autoreload
# %autoreload 2

from stipy import *
from makeDevMeas import *

# %%
did = DeviceID("STI Server", "localhost", 0)
server = connect(did, "192.168.1.4:2809")
# Out:
# ++++ DeviceCollectionListener::add( localhost/0/STI Server )

# %%
printNetwork("STI","STI")
# Out:
# ''

# %%
s=server.makeshot(f)

# %%
s.rootgroup().events()[0].type()
# Out:
# <RawEventType.Measurement: 1>

# %%
tick=server.parse(s)

# %%
tick.status()
# Out:
# <TicketStatus.Complete: 1>

# %%
result = server.play(tick)

# %%
result.status()
# Out:
# <TicketStatus.Complete: 1>
# ---- DeviceCollectionListener::remove( localhost/0/STI Server )

# %%
tick.cancel()

# %%
tmp=DeviceID("localhost/0/STI Server")

# %%
res=tick.getParseResult()

# %%
res
# Out:
# <ParseResult | pid:@#00_33_31_993093356>

# %%
tree=res.parsedDevices

# %%
tree.getDependedentNodes(tmp)
# Out:
# []

# %%
tick.getParseResult().parsedDevices.getDependedentNodes(tmp)
# Out:
# [localhost/0/dev3]

# %%
tick.rootgroup().getEvents()[0]
# Out:
# meas(Time=200ns, Channel=dev(localhost2/0/TestDevice).ch(3), Value=None)

# %%
result = server.play(tick)
result.wait()
tmp=DeviceID("localhost2/0/TestDevice")
res=result.getShotResult().getMeasurements()[tmp]
print(res)
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]

# %%
result.getParseResult().pid.shotConfig.jobSourceID
# Out:
# @

# %%
result.getShotResult().sid
# Out:
# sid:@#02_29_23_610107033

# %%
result.getShotID()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Unregistered type : STI::Engine::ShotID
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 result.getShotID()
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	(self: stipy.bin.stipy.ResultTicket) -> STI::Engine::ShotID

# %%
result
# Out:
# <TicketStatus.Complete: 1>

# %%
result.getParseResult()

# %%
tmp=DeviceID("localhost2/0/TestDevice")
result.getShotResult().getMeasurements()[tmp]
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]

# %%
result.getShotResult().getMeasurements()
# Out:
# {localhost2/0/TestDevice: [<Time=200ns, Channel=3, Type=Empty, Value=<Empty>>]}
# ---- DeviceCollectionListener::remove( localhost/0/STI Server )
# ++++ DeviceCollectionListener::add( localhost/0/STI Server )

# %%
tmp=DeviceID("localhost/0/dev3")
result.measurements(tmp)
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]

# %%
result.measurements("localhost/0/dev3")
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]
# ---- DeviceCollectionListener::remove( localhost/0/STI Server )
# ++++ DeviceCollectionListener::add( localhost/0/STI Server )

# %%
result.measurements("localhost/0/dev3")[0].data()
# Out:
# 256

# %%
list(result.getShotResult().attributes.keys())[0]
# Out:
# localhost/0/STI Server

# %%
result.getShotResult().attributes[DeviceID("localhost/0/dev3")]['test']
# Out:
# '33'
# ---- DeviceCollectionListener::remove( localhost/0/STI Server )
# ++++ DeviceCollectionListener::add( localhost/0/STI Server )

# %%
result.getShotResult().shotResultRecord
# Out:
# <ShotResultRecord (localhost/0/STI Server) | Complete | Dependencies: 1>

# %%
from PIL import Image

# %%
image = Image.open('/home/hogan/Desktop/frames/frames1_13.png')

# %%
image.show()

# %%
image.height
# Out:
# 400

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x400>

# %%
imgData=image.tobytes()
Image.frombytes('RGB', (image.width, image.height), imgData)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>
