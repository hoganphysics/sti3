# %%
# %load_ext autoreload
# %autoreload 2

from stipy import *
from makeDevMeas import *

# %%
did = DeviceID("STI Server", "localhost", 0)
server = connect("localhost", did, "192.168.1.4:2809")
# Out:
# ++++ DeviceCollectionListener::add( localhost/0/STI Server )

# %%
s=server.makeshot(f)

# %%
s.rootgroup().getEvents()[0].type()
# Out:
# <RawEventType.MeasurementEvent: 1>

# %%
tick=server.parse(s)

# %%
tick.getMessages()
# Out:
# []

# %%
tmp=DeviceID("localhost/0/STI Server")

# %%
res=tick.getParseResult()
# Out:
# convert<TEventEngineDependencyTree,EventEngineDependencyTree>
# ** (T->sti) ** id: localhost/0/STI Server outConnections.length() = 1
# **** (T->sti) addEdge: localhost/0/STI Server -> localhost/0/dev3
# ** (T->sti) ** id: localhost/0/dev3 outConnections.length() = 0
# ParsedDependencyTree::ParsedDependencyTree(tree)
# ++ node: localhost/0/STI Server
# ++++ dependents.size(): 1
# ++ node: localhost/0/dev3
# ++++ dependents.size(): 0

# %%
tree=res.parsedDevices

# %%
tree.getDependedentNodes(tmp)
# Out:
# [localhost/0/dev3]
# ParsedDependencyTree::getDependedentNodes(localhost/0/STI Server)
# ** found vertex: localhost/0/STI Server
# **** outConnection index: 1
# ****** push_back: localhost/0/dev3

# %%
tick.getParseResult().parsedDevices.getDependedentNodes(tmp)
# Out:
# ParsedDependencyTree::getDependedentNodes(localhost/0/dev3)
# ** found vertex: localhost/0/dev3
# **** outConnection index: 1
# ****** push_back: localhost/0/dev3
# [localhost/0/dev3]

# %%
tick.rootgroup().getEvents()[0]
# Out:
# meas(Time=200ns, Channel=dev(localhost/0/dev3).ch(2), Value=None)

# %%
result = server.play(tick)

# %%
tmp=DeviceID("localhost/0/dev3")
result.getShotResult().getMeasurements("localhost/0/dev3")
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]

# %%
tmp=DeviceID("localhost/0/dev3")
result.measurements(tmp)
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]

# %%
result.measurements("localhost/0/dev3")
# Out:
# [<Time=200ns, Channel=2, Type=Int, Value=256>]

# %%
list(result.getShotResult().attributes.keys())[0]
# Out:
# localhost/0/STI Server

# %%
result.getShotResult().attributes[DeviceID("localhost/0/dev3")]['test']
# Out:
# '33'

# %%
result.getShotResult().shotResultRecord
# Out:
# <ShotResultRecord (localhost/0/STI Server) | Complete | Dependencies: 1>
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
