# %%
from stipy import *

# %%
testDevice = connect(DeviceID("TestDevice", "localhost2", 0), "192.168.1.4:2809")
# Out:
# ++++ DeviceCollectionListener::add( localhost2/0/TestDevice )

# %%
testDevice.getTaskManager().getTaskIDs()
# Out:
# {'Log::Read channel #2(test channel)',
#  'Log::Task:0',
#  'Log:ch1:Write channel #1(test channel)'}
# ---- DeviceCollectionListener::remove( localhost2/0/TestDevice )

# %%
testDevice.getTaskManager().deactivateTask('Log::Read channel #2(test channel)')

# %%
t1=testDevice.getTaskManager().getTask('Log::Read channel #2(test channel)')

# %%
t1.getStatus()
# Out:
# <TaskStatus.Inactive: 1>
# ---- DeviceCollectionListener::remove( localhost2/0/TestDevice )

# %%
testDevice.getTaskManager().setStatus(t1.getID(), TaskStatus.Inactive)

# %%
t1.secondsToNextRun()
# Out:
# 0.0

# %%
t1=testDevice.getTaskManager().getTasks()

# %%
[t.getStatus() for t in t1]
# Out:
# [<TaskStatus.Inactive: 1>, <TaskStatus.Active: 0>, <TaskStatus.Active: 0>]

# %%
testDevice.getChannelManager().getChannels()
# Out:
# [<ch=1|name=test name 7|type=Output|in=Double|out=Double>,
#  <ch=2|name=hello 24|type=Input|in=Double|out=Empty>,
#  <ch=3|name=file measurement|type=Input|in=File|out=Empty>,
#  <ch=4|name=vector input|type=Input|in=Double|out=Vector>]

# %%
p1=testDevice.getProfileManager().getProfile("test")

# %%
p1.attributeData
# Out:
# MapStringString{x: 44, y: 66, z: 100}

# %%
p1.channelData[2]=MixedValue(34)
p1.channelData[1]=MixedValue(13.5)

# %%
p1.channelData
# Out:
# {1: 13.5, 2: 22}
# ---- DeviceCollectionListener::remove( localhost2/0/TestDevice )

# %%
p1.attributeData["x"]="44"
p1.attributeData["y"]="77"

# %%
p1.attributeData
# Out:
# MapStringString{x: 44, y: 77}

# %%
p1.channelData[2].getType()
# Out:
# <MixedValueType.Int: 2>

# %%
testDevice.getProfileManager().saveProfile(p1)
# Out:
# True
# ---- DeviceCollectionListener::remove( localhost2/0/TestDevice )

# %%
p1t=testDevice.getProfileManager().getProfile("test")

# %%
p1t.attributeData
# Out:
# MapStringString{x: 44, y: 77}

# %%
p1t.channelData
# Out:
# {1: 13.5, 2: 34}

# %%
p1t.channelData[1]
# Out:
# 13.5

# %%
len(p1t.channelData)
# Out:
# 1

# %%
pm=testDevice.getProfileManager()

# %%
pm.saveCurrentProfile("safe", ProfileType.Attribute, False)
# Out:
# True

# %%
pm.getProfiles()
# Out:
# {'test'}

# %%
pm.getProfile("test")
# Out:
# <Profile | 'test'>

# %%
pm.loadProfile("test", ProfileType.All, False)
# Out:
# False

# %%
testDevice.getAttributeManager().getAttributes()
# Out:
# [<key=clock time, value=28, group=>, <key=x, value=44, group=>]

# %%
testDevice.getChannelManager().getChannels()[0]
# Out:
# <ch=1|name=test|type=Output|in=Empty|out=Double>

# %%
testDevice.getChannelManager().getChannels()[0].getLastValue()
# Out:
# 13.5

# %%
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'activateTask',
#  'clear',
#  'deactivateTask',
#  'getTask',
#  'getTaskIDs',
#  'getTaskStatus',
#  'getTasks',
#  'removeTask',
#  'runTask']
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
