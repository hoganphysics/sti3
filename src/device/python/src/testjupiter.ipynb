# %%
print('Hello')
# Out:
# Hello

# %%
from testSTI import *

# %%
testSum(3,5)
# Out:
# 13

# %%
e=STIEvent(2.1, 4, "Hi")
e.toString()
# Out:
# 2.1
# 4
# Hi

# %%
server=STIServer()
server.parse()

event(1.1, 33, "test")
event(2.1, 1, "another")

server2=STIServer()
server2.parse()
event(1.5, 3, "server2")

# %%
server2.events

# %%
server.events[1].toString()
# Out:
# 2.1
# 1
# another

# %%
event(1.1, 33, "mot1")

# %%
def makeMOT():
    event(1.1, 33, "mot1")
    event(2.1, 1, "mot2")

server3=STIServer()
server3.parse2(makeMOT)

server3.events[0].toString()
# Out:
# 1.1
# 33
# mot1

# %%
e2=STIEvent(2.1, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-58defe669a3a> in <module>
# ----> 1 e2=STIEvent(2.1, 5)
#
# TypeError: __init__() missing 1 required positional argument: 'value'

# %%
c1=achannel("3dAOM")

ch(dds0, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-eaad908bc51d> in <module>
# ----> 1 c1=achannel("3dAOM")
#       2
#       3 ch(dds0, 3)
#
# NameError: name 'achannel' is not defined

# %%
channelsFrame1 = {
    "3dAOM": ch(dds0, 3),
    "2dAOM": ach("DDS0", 2),
    "zSlower": ch(dds0, 0),
    "DDS0": dev("DDS", "192.168.1.4", 0)
}

# %%
c1.event(time, value)
dds0.event(time, 2, (10,100,0))
