# %%
from STI import *
import STI

# %%
server=STIServer()
# Out:
# Currently in <module 'STI' from '/home/hogan/code/dev/sti3/src/device/python/src/STI.py'>.__init__
# FrameInfo(frame=<frame object at 0x2efa9c8>, filename='<ipython-input-2-763dc3dc1049>', lineno=1, function='<module>', code_context=['server=STIServer()\n'], index=0)

# %%
def makeMot() :
    dds=dev("DDS", "localhost", 0, "as1")
    bragg=ch(dds, 1)
    setvar('omega1', 22)
    event(1.1, bragg, 55)

# %%
setvar('x', 33)

# %%
getattr(STI, "x")
# Out:
# 33

# %%
from STI import x

# %%
x
# Out:
# 33

# %%
server.events[0].channel.device.name
# Out:
# 'DDS'

# %%
server.parse(makeMot)

# %%
server.vars

# %%
[x.name for x in server.vars]
# Out:
# ['omega1', 'x']
